# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os

# Print the current working directory
print("Current Working Directory:", os.getcwd())

# Change the current working directory
new_directory = "/content/drive/MyDrive/Colab Notebooks/Agentic Systems Term Project/"
try:
    os.chdir(new_directory)
    print("Directory changed to:", os.getcwd())
except FileNotFoundError:
    print("The specified directory does not exist.")
except PermissionError:
    print("You do not have permissions to change to this directory.")
# Out:
# Current Working Directory: /content
# Directory changed to: /content/drive/MyDrive/Colab Notebooks/Agentic Systems Term Project

# %%
from google.colab import userdata

# %%
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
os.environ["HF_TOKEN"] = userdata.get('HF_TOKEN')

# %%
os.environ["OPENAI_API_KEY"] = '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'
os.environ["HF_TOKEN"] = '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'

# %%
# !pip install -q "transformers>=4.50.0" accelerate peft timm gradio pydicom pillow openai sqlalchemy
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 39.7 MB/s eta 0:00:00

# %%
# %run cxr_agent_agentic/main.py
# Out:
# OpenAI client initialised.
# Classifier missing keys: []
# Classifier unexpected keys: []
# /usr/local/lib/python3.12/dist-packages/gradio/utils.py:1052: UserWarning: Expected 3 arguments for function <function on_history_select at 0x78461c89e980>, received 2.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/gradio/utils.py:1056: UserWarning: Expected at least 3 arguments for function <function on_history_select at 0x78461c89e980>, received 2.
#   warnings.warn(
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://fd96558605c18bb5e4.gradio.live
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
